# %%
import numpy as np
import os, json

# %%
word2ix = json.load(open('word2ix.json'))
src_ix2word = { v:k for k,v in word2ix['src'].items() }
tar_ix2word = { v:k for k,v in word2ix['target'].items() }
data_dict = json.load(open('train.json'))

# %%
unk_count = 0
N = len(data_dict)
for i in range(100):
    for ix in data_dict[i]["src_ixs"]:
        if src_ix2word[ix]=="<unk>":
            unk_count+=1
            print('here {}'.format(i))
# Out:
# here 0
# here 1
# here 1
# here 1
# here 1
# here 1
# here 1
# here 1
# here 1
# here 1
# here 2
# here 2
# here 2
# here 3
# here 3
# here 4
# here 5
# here 5
# here 5
# here 6
# here 7
# here 7
# here 7
# here 7
# here 8
# here 8
# here 8
# here 9
# here 9
# here 9
# here 9
# here 9
# here 9
# here 9
# here 11
# here 11
# here 11
# here 11
# here 11
# here 11
# here 13
# here 13
# here 13
# here 13
# here 13
# here 13
# here 14
# here 14
# here 14
# here 14
# here 15
# here 15
# here 15
# here 15
# here 16
# here 17
# here 17
# here 18
# here 19
# here 20
# here 20
# here 20
# here 20
# here 20
# here 20
# here 20
# here 20
# here 22
# here 22
# here 22
# here 22
# here 22
# here 22
# here 22
# here 22
# here 23
# here 23
# here 23
# here 23
# here 23
# here 23
# here 23
# here 23
# here 23
# here 23
# here 23
# here 24
# here 24
# here 24
# here 26
# here 26
# here 26
# here 28
# here 31
# here 34
# here 34
# here 34
# here 34
# here 34
# here 35
# here 36
# here 36
# here 37
# ...

# %%
print(unk_count)
# Out:
# 52597

# %%
data_dict[1]
# Out:
# {'src_ixs': [22664,
#   201,
#   102,
#   123,
#   1,
#   19755,
#   925,
#   215,
#   29940,
#   1,
#   1,
#   1,
#   1,
#   1,
#   1,
#   1,
#   12,
#   201,
#   1785,
#   4081,
#   3,
#   282,
#   7,
#   972,
#   360,
#   1,
#   14013,
#   4081,
#   1586,
#   89],
#  'src_sent': '憲宗 八 年 受 散吉 令旨 管 領 李春 文大純 趙奧 魯哥兒 卓靑 尙哉 光奕 張哥 等 八 介 百戶 之 任 上 充 兼 扢 扎 百戶 句 當',
#  'target_ixs': [166,
#   462,
#   163,
#   14,
#   161,
#   464,
#   397,
#   8,
#   20478,
#   13,
#   10177,
#   9,
#   82,
#   36,
#   5,
#   215,
#   14,
#   107,
#   18488,
#   85,
#   66,
#   619,
#   18,
#   36,
#   36,
#   1164,
#   108,
#   6577,
#   399,
#   1824,
#   8082,
#   40,
#   464,
#   417,
#   79,
#   300,
#   9,
#   7249,
#   4,
#   16,
#   1188,
#   8,
#   1067,
#   42,
#   12,
#   1180,
#   22,
#   8772,
#   228,
#   28,
#   4860,
#   1179,
#   9,
#   905,
#   27,
#   42,
#   10,
#   6,
#   3],
# ...

# %%
word2ix['src']
# Out:
# {u'\u5e73\u5b9a': 33882,
#  u'\u7ae6\u7136': 33883,
#  u'\u6d89': 1151,
#  u'\u771e\u91d1': 37261,
#  u'\u611b\u9999': 24833,
#  u'\u4efb\u5b88\u6b63': 15331,
#  u'\u5e73\u5b89': 16263,
#  u'\u5eab\u5b50': 14488,
#  u'\u8aa4\u66f8': 30471,
#  u'\u6116': 28356,
#  u'\u8599': 37263,
#  u'\u88c1\u6e1b': 12821,
#  u'\u674e\u6210\u5ff1': 23383,
#  u'\u7533\u6dd1\u6839': 33884,
#  u'\u674e\u5b85\u93ad': 8046,
#  u'\u5f90\u6d69\u4fee': 2513,
#  u'\u7926': 30472,
#  u'\u592a\u50d5': 21139,
#  u'\u5916\u59ea': 37264,
#  u'\u6cb3': 1254,
#  u'\u82f1\u9675\u53c3\u5949': 17399,
#  u'\u5f35\u6966': 30474,
#  u'\u5dfe\u5e45': 37265,
#  u'\u6734\u57fa\u5b8f': 21144,
#  u'\u907c\u967d': 16766,
#  u'\u597d\u8272': 26325,
#  u'\u59d3\u8af1': 28357,
#  u'\u9ec3\u4e00\u7693': 21140,
#  u'\u53cd': 814,
#  u'\u6309\u5f8b': 7031,
#  u'\u9673\u66f8': 20020,
#  u'\u5fcd\u51ac\u8336': 37267,
#  u'\u67f3\u7199\u7dd6': 8833,
#  u'\u6c34\u539f\u5e9c': 4867,
#  u'\u5225\u4e0b\u7a0b': 14955,
# ...
